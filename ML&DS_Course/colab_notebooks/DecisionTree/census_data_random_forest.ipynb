# %% [markdown]
# #Random Forest

# %% [markdown]
# ##Load Data

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4979ec9e-6978-4878-9a65-370a8390bfa2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4979ec9e-6978-4878-9a65-370a8390bfa2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving census.pkl to census.pkl

# %%
import pickle

with open('census.pkl', mode = 'rb') as f:
  X_data_train, y_data_train, X_data_test, y_data_test = pickle.load(f)

# %% [markdown]
# #Model Training

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=10)
classifier.fit(X_data_train, y_data_train)
predict = classifier.predict(X_data_test)
predict
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(predict, y_data_test)
# Out:
# 0.8438075742067553

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(classifier);
cm.fit(X_data_train, y_data_train);
cm.score(X_data_test, y_data_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# 0.8425793244626407
