# %% [markdown]
# #Decision Tree

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-34b81a0a-4be5-456a-a448-f1b8fdf8518c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34b81a0a-4be5-456a-a448-f1b8fdf8518c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving risco_credito.csv to risco_credito.csv
# {'risco_credito.csv': b'historia,divida,garantias,renda,risco\r\nruim,alta,nenhuma,0_15,alto\r\ndesconhecida,alta,nenhuma,15_35,alto\r\ndesconhecida,baixa,nenhuma,15_35,moderado\r\ndesconhecida,baixa,nenhuma,acima_35,alto\r\ndesconhecida,baixa,nenhuma,acima_35,baixo\r\ndesconhecida,baixa,adequada,acima_35,baixo\r\nruim,baixa,nenhuma,0_15,alto\r\nruim,baixa,adequada,acima_35,moderado\r\nboa,baixa,nenhuma,acima_35,baixo\r\nboa,alta,adequada,acima_35,baixo\r\nboa,alta,nenhuma,0_15,alto\r\nboa,alta,nenhuma,15_35,moderado\r\nboa,alta,nenhuma,acima_35,baixo\r\nruim,alta,nenhuma,15_35,alto'}

# %%
data = pd.read_csv("credit_risk.csv")
data
# Out:
#         historia divida garantias     renda     risco
# 0           ruim   alta   nenhuma      0_15      alto
# 1   desconhecida   alta   nenhuma     15_35      alto
# 2   desconhecida  baixa   nenhuma     15_35  moderado
# 3   desconhecida  baixa   nenhuma  acima_35      alto
# 4   desconhecida  baixa   nenhuma  acima_35     baixo
# 5   desconhecida  baixa  adequada  acima_35     baixo
# 6           ruim  baixa   nenhuma      0_15      alto
# 7           ruim  baixa  adequada  acima_35  moderado
# 8            boa  baixa   nenhuma  acima_35     baixo
# 9            boa   alta  adequada  acima_35     baixo
# 10           boa   alta   nenhuma      0_15      alto
# 11           boa   alta   nenhuma     15_35  moderado
# 12           boa   alta   nenhuma  acima_35     baixo
# 13          ruim   alta   nenhuma     15_35      alto

# %%
X_data = data.iloc[:, 0:4].values
y_data = data.iloc[:, 4].values

# %%
from sklearn.preprocessing import LabelEncoder

def labelEncFunc(data):
  for i in range(len(data[0])):
    if (not str(data[0][i]).isnumeric()):
      label_encoder = LabelEncoder()
      data[:,i] = label_encoder.fit_transform(X_data[:,i])
  return data

# %%
X_data = labelEncFunc(X_data)
X_data[0]
# Out:
# array([2, 0, 1, 0], dtype=object)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion="entropy")
classifier.fit(X_data, y_data)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
predict = classifier.predict(X_data)
predict
# Out:
# array(['alto', 'alto', 'moderado', 'alto', 'alto', 'baixo', 'alto',
#        'moderado', 'baixo', 'baixo', 'alto', 'moderado', 'baixo', 'alto'],
#       dtype=object)

# %%
def accuracy(predict, real):
  count = 0
  for i in range(len(predict)):
    count += 1 if predict[i] == real[i] else 0
  return float (count)/len(real)

accuracy(predict, y_data)
# Out:
# 0.9285714285714286
