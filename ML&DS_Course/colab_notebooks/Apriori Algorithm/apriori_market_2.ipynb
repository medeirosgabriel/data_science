# %% [markdown]
# #Apriori Algorithm

# %% [markdown]
# ##Load Data

# %%
# !pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=bab6cede1922f541b0c160c7b6dc326b38c15706963118f084c9ba98fe481191
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
import pandas as pd
from apyori import apriori
data = pd.read_csv("mercado2.csv", header=None)
data
# Out:
#                  0                  1   ...       18         19
# 0            shrimp            almonds  ...  spinach  olive oil
# 1           burgers          meatballs  ...      NaN        NaN
# 2           chutney                NaN  ...      NaN        NaN
# 3            turkey            avocado  ...      NaN        NaN
# 4     mineral water               milk  ...      NaN        NaN
# ...             ...                ...  ...      ...        ...
# 7496         butter         light mayo  ...      NaN        NaN
# 7497        burgers  frozen vegetables  ...      NaN        NaN
# 7498        chicken                NaN  ...      NaN        NaN
# 7499       escalope          green tea  ...      NaN        NaN
# 7500           eggs    frozen smoothie  ...      NaN        NaN
#
# [7501 rows x 20 columns]

# %%
l = []
for i in range(data.shape[0]):
  l.append([str(data.values[i, j]) for j in range(data.shape[1])])
l, type(l)
# Out:
# ([['shrimp',
#    'almonds',
#    'avocado',
#    'vegetables mix',
#    'green grapes',
#    'whole weat flour',
#    'yams',
#    'cottage cheese',
#    'energy drink',
#    'tomato juice',
#    'low fat yogurt',
#    'green tea',
#    'honey',
#    'salad',
#    'mineral water',
#    'salmon',
#    'antioxydant juice',
#    'frozen smoothie',
#    'spinach',
#    'olive oil'],
#   ['burgers',
#    'meatballs',
#    'eggs',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan'],
#   ['chutney',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan'],
#   ['turkey',
#    'avocado',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
#    'nan',
# ...

# %%
rules = apriori(l, min_support = 0.003, min_confidence = 0.2, min_lift = 2)
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'almonds', 'burgers'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]),
#  RelationRecord(items=frozenset({'spaghetti', 'bacon'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'spaghetti'}), confidence=0.36923076923076925, lift=2.1206738131699847)]),
#  RelationRecord(items=frozenset({'black tea', 'milk'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'black tea'}), items_add=frozenset({'milk'}), confidence=0.29906542056074764, lift=2.3079112341833006)]),
# ...

# %%
A = []
B = []
support = []
confidence = []
lift = []
for result in results:
  s = result[1]
  result_rules = result[2]
  for result_rule in result_rules:
    a = list(result_rule[0])
    b = list(result_rule[1])
    c = result_rule[2]
    l = result_rule[3]
    print(a,"-",b,"-",c,"-",l)
    A += [a]
    B += [b]
    support += [s]
    confidence += [c]
    lift += [l]
# Out:
# ['almonds'] - ['burgers'] - 0.25490196078431376 - 2.923577382023146
# ['bacon'] - ['spaghetti'] - 0.36923076923076925 - 2.1206738131699847
# ['black tea'] - ['milk'] - 0.29906542056074764 - 2.3079112341833006
# ['blueberries'] - ['spaghetti'] - 0.37681159420289856 - 2.164214217546663
# ['body spray'] - ['french fries'] - 0.37209302325581395 - 2.17712150346479
# ['ham'] - ['burgers'] - 0.21105527638190955 - 2.420681388594348
# ['cereals'] - ['milk'] - 0.2746113989637306 - 2.119197637476279
# ['light cream'] - ['chicken'] - 0.29059829059829057 - 4.84395061728395
# ['tomato sauce'] - ['chocolate'] - 0.3584905660377358 - 2.1879883936932925
# ['cider'] - ['eggs'] - 0.4050632911392405 - 2.2539909101153137
# ['cider'] - ['milk'] - 0.31645569620253167 - 2.4421133510444344
# ['mushroom cream sauce'] - ['escalope'] - 0.3006993006993007 - 3.790832696715049
# ['pasta'] - ['escalope'] - 0.3728813559322034 - 4.700811850163794
# ...

# %%
A, B, support, confidence, lift
# Out:
# ([['almonds'],
#   ['bacon'],
#   ['black tea'],
#   ['blueberries'],
#   ['body spray'],
#   ['ham'],
#   ['cereals'],
#   ['light cream'],
#   ['tomato sauce'],
#   ['cider'],
#   ['cider'],
#   ['mushroom cream sauce'],
#   ['pasta'],
#   ['extra dark chocolate'],
#   ['flax seed'],
#   ['fresh tuna'],
#   ['fromage blanc'],
#   ['parmesan cheese'],
#   ['shrimp'],
#   ['tomatoes'],
#   ['grated cheese'],
#   ['green beans'],
#   ['herb & pepper'],
#   ['light cream'],
#   ['olive oil'],
#   ['pepper'],
#   ['rice'],
#   ['salmon'],
#   ['ground beef'],
#   ['spaghetti'],
#   ['tomato sauce'],
#   ['light cream'],
#   ['light cream'],
#   ['light mayo'],
#   ['meatballs'],
#   ['soup'],
#   ['whole wheat pasta'],
#   ['nonfat milk'],
#   ['whole wheat pasta'],
#   ['pasta'],
#   ['pepper'],
#   ['red wine'],
#   ['strong cheese'],
#   ['tomato sauce'],
#   ['almonds'],
#   ['almonds', 'nan'],
#   ['mineral water', 'avocado'],
#   ['avocado', 'milk'],
#   ['avocado', 'spaghetti'],
# ...

# %%
rules_df = pd.DataFrame({"A": A, "B": B, "support": s, "confidence": confidence, "lift": lift})
rules_df.sort_values(by='lift', ascending=False)
# Out:
#                                         A  ...      lift
# 1064            [frozen vegetables, soup]  ...  7.987176
# 1653            [frozen vegetables, soup]  ...  7.987176
# 1658       [frozen vegetables, nan, soup]  ...  7.987176
# 1059       [frozen vegetables, olive oil]  ...  6.128268
# 1647  [frozen vegetables, nan, olive oil]  ...  6.128268
# ...                                   ...  ...       ...
# 738             [escalope, mineral water]  ...  2.002657
# 156             [escalope, mineral water]  ...  2.002657
# 107                      [pancakes, cake]  ...  2.000542
# 636                      [pancakes, cake]  ...  2.000542
# 638                 [pancakes, nan, cake]  ...  2.000542
#
# [1741 rows x 5 columns]
