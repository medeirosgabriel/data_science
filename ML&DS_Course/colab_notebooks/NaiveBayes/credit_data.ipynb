# %% [markdown]
# #Naive Bayes

# %% [markdown]
# ##Load Data

# %%
from google.colab import files
files.upload()

# %%
import pickle
with open('census.pkl', mode = 'wb') as f:
  X_data_train, X_data_test, y_data_train, y_data_test = pickle.load(f)

# %% [markdown]
# #Model Training

# %%
from sklearn.naive_bayes import GaussianNB
naive = GaussianNB()

# %%
naive.fit(X_data_train, y_data_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
predict = naive.predict(X_data_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_score(predict, y_data_test)
# Out:
# 0.912

# %%
confusion_matrix(predict, y_data_test)
# Out:
# array([[417,  30],
#        [ 14,  39]])

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(naive)
cm.fit(X_data_train, y_data_train)
cm.score(X_data_test, y_data_test)
# Out:
# 0.912
